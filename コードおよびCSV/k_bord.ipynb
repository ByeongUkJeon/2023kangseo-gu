# %%
import pandas as pd

# %%
data = pd.read_csv('kbd.csv', encoding='cp949')

# %%
data.head()
# Out:
#    번호         신고일  구정보                     주소                  유형         조치일
# 0   1  2021-07-15  동작구   서울특별시 동작구 상도동 215-45      점자블록, 엘리베이터 입구  2021-07-15
# 1   2  2021-07-15  동작구   서울특별시 동작구 상도동 172-28               보도 중앙  2021-07-15
# 2   3  2021-07-15  동작구    서울특별시 동작구 대방동 356-2       버스정류장, 택시 승강장  2021-07-15
# 3   4  2021-07-15  동작구    서울특별시 동작구 대방동 354-1       버스정류장, 택시 승강장  2021-07-15
# 4   5  2021-07-15  동작구  서울특별시 동작구 신대방동 460-30  보도와 차도가 구분된 도로의 차도  2021-07-15

# %%
sibal = data['주소']

# %%
tmp = data.loc[data['구정보']=='강서구']

# %%
tmp['주소'] = tmp['주소'].str.replace('서울특별시','')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10680\4168884302.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['주소'] = tmp['주소'].str.replace('서울특별시','')

# %%
tmp['주소'] = tmp['주소'].str.replace('강서구','')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10680\1125702327.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['주소'] = tmp['주소'].str.replace('강서구','')

# %%
tmp.head()
# Out:
#           번호         신고일  구정보      주소                  유형         조치일
# 12443  12444  2021-11-03  강서구    화곡동                   기타  2021-11-03
# 12530  12531  2021-11-03  강서구    등촌동       점자블록, 엘리베이터 입구  2021-11-03
# 12608  12609  2021-11-03  강서구    마곡동   보도와 차도가 구분된 도로의 차도  2021-11-03
# 12821  12822  2021-11-04  강서구    가양동          횡단보도, 산책로 등  2021-11-04
# 12824  12825  2021-11-04  강서구    가양동       지하철역 진출입로 및 주변  2021-11-04

# %%
tmp['주소'] = tmp['주소'].str.slice(start =0 , stop = 6)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10680\21274513.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tmp['주소'] = tmp['주소'].str.slice(start =0 , stop = 6)

# %%
tmp.head()
# Out:
#           번호         신고일  구정보      주소                  유형         조치일
# 12443  12444  2021-11-03  강서구    화곡동                   기타  2021-11-03
# 12530  12531  2021-11-03  강서구    등촌동       점자블록, 엘리베이터 입구  2021-11-03
# 12608  12609  2021-11-03  강서구    마곡동   보도와 차도가 구분된 도로의 차도  2021-11-03
# 12821  12822  2021-11-04  강서구    가양동          횡단보도, 산책로 등  2021-11-04
# 12824  12825  2021-11-04  강서구    가양동       지하철역 진출입로 및 주변  2021-11-04

# %%
kick = pd.DataFrame(tmp['주소'].value_counts())
kick
# Out:
#          주소
#   화곡동   524
#   마곡동   524
#   등촌동   494
#   가양동   262
#   염창동   223
#   내발산동  222
#   방화동   169
#   공항동    61
#   외발산동    2

# %%
data['구정보'].value_counts()
# Out:
# 마포구     7408
# 송파구     6492
# 영등포구    5381
# 성동구     4119
# 동작구     3949
# 관악구     3877
# 서초구     3316
# 강남구     3234
# 광진구     2690
# 강서구     2481
# 강동구     2294
# 동대문구    2023
# 용산구     1701
# 중랑구     1683
# 서대문구    1431
# 도봉구     1387
# 구로구     1373
# 양천구     1242
# 노원구     1032
# 종로구      998
# 중구       915
# 성북구      706
# 강북구      528
# 은평구      343
# 금천구        2
# Name: 구정보, dtype: int64

# %%
s_move = pd.read_csv('seoul_moving.csv', encoding='cp949')

# %%
s_move.head()
# Out:
#       기준일ID  시간대구분     행정동코드      총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0  20230306      0  11500510  33647.8423      1748.7085         905.0208
# 1  20230306      0  11500520  23277.8841       649.2871         308.5875
# 2  20230306      0  11500530  18660.6716       702.8644         361.4494
# 3  20230306      0  11500535  36191.1029       880.3233         520.9542
# 4  20230306      0  11500540  54000.0900      1605.0279         574.2353
#
#    남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  ...  \
# 0         775.6978         544.0711        1029.6294        1502.2811  ...
# 1         406.0973         496.4329        1100.6099        1395.9748  ...
# 2         534.6433         474.4733         626.7361         818.9797  ...
# 3         793.0212         753.7243        1299.1798        1441.8210  ...
# 4         794.0980        1380.8730        2900.9194        2963.4229  ...
#
#    여자25세부터29세생활인구수  여자30세부터34세생활인구수  여자35세부터39세생활인구수  여자40세부터44세생활인구수  \
# ...

# %%
df = s_move.groupby('행정동코드')['남자20세부터24세생활인구수', '남자25세부터29세생활인구수', '여자20세부터24세생활인구수','여자25세부터29세생활인구수'].sum()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_10680\3404752310.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df = s_move.groupby('행정동코드')['남자20세부터24세생활인구수', '남자25세부터29세생활인구수', '여자20세부터24세생활인구수','여자25세부터29세생활인구수'].sum()

# %%
df.head()
# Out:
#           남자20세부터24세생활인구수  남자25세부터29세생활인구수  여자20세부터24세생활인구수  여자25세부터29세생활인구수
# 행정동코드
# 11500510     7.433650e+05     1.261688e+06     1.032193e+06     1.536573e+06
# 11500520     7.157746e+05     1.311429e+06     1.017219e+06     1.881020e+06
# 11500530     5.657149e+05     6.752541e+05     5.794299e+05     8.243876e+05
# 11500535     1.302179e+06     1.833941e+06     1.709881e+06     2.420529e+06
# 11500540     1.696487e+06     3.028972e+06     2.144851e+06     3.414501e+06

# %%
df.index
# Out:
# Int64Index([11500510, 11500520, 11500530, 11500535, 11500540, 11500550,
#             11500560, 11500570, 11500590, 11500591, 11500593, 11500603,
#             11500604, 11500605, 11500611, 11500615, 11500620, 11500630,
#             11500640, 11500641],
#            dtype='int64', name='행정동코드')

# %%
df['행정동'] = ['염차동', '등촌제1동', '등촌제2동', '등촌제3동', '화곡제1동', '화곡제2동' ,'화곡제3동', '화곡제4동','화곡본동', '화곡제6동', '화곡제8동', '가양제1동', '가양제2동','가양제3동','발산제1동','우장산동','공항동','방화제1동', '방화제2동','방화제3동']

# %%
df
# Out:
#           남자20세부터24세생활인구수  남자25세부터29세생활인구수  여자20세부터24세생활인구수  여자25세부터29세생활인구수  \
# 행정동코드
# 11500510     7.433650e+05     1.261688e+06     1.032193e+06     1.536573e+06
# 11500520     7.157746e+05     1.311429e+06     1.017219e+06     1.881020e+06
# 11500530     5.657149e+05     6.752541e+05     5.794299e+05     8.243876e+05
# 11500535     1.302179e+06     1.833941e+06     1.709881e+06     2.420529e+06
# 11500540     1.696487e+06     3.028972e+06     2.144851e+06     3.414501e+06
# 11500550     4.287762e+05     6.004788e+05     4.386875e+05     6.252461e+05
# 11500560     6.445144e+05     8.463203e+05     8.690471e+05     9.857967e+05
# 11500570     5.180012e+05     7.584776e+05     6.250154e+05     7.773874e+05
# 11500590     1.011339e+06     1.668666e+06     1.270230e+06     1.924997e+06
# 11500591     7.269923e+05     1.315883e+06     9.485814e+05     1.547032e+06
# 11500593     1.084375e+06     1.658263e+06     1.389281e+06     1.897024e+06
# ...

# %%
asd = df.loc[df['행정동'].str.slice(start = 0, stop = 2) == '등촌']
asd
# Out:
#           남자20세부터24세생활인구수  남자25세부터29세생활인구수  여자20세부터24세생활인구수  여자25세부터29세생활인구수  \
# 행정동코드
# 11500520     7.157746e+05     1.311429e+06     1.017219e+06     1.881020e+06
# 11500530     5.657149e+05     6.752541e+05     5.794299e+05     8.243876e+05
# 11500535     1.302179e+06     1.833941e+06     1.709881e+06     2.420529e+06
#
#             행정동
# 행정동코드
# 11500520  등촌제1동
# 11500530  등촌제2동
# 11500535  등촌제3동

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (20,5))
plt.rc('font', family='Malgun Gothic')
plt.plot(df['행정동'], df['남자20세부터24세생활인구수'])
plt.grid()
plt.show()

# %%
a.head()
# Out:
#           행정동코드
# 11500510   1320
# 11500520   1320
# 11500640   1320
# 11500630   1320
# 11500620   1320
